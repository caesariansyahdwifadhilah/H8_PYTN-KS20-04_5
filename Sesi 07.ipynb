# %%
import numpy as np
import pandas as pd

# %%
url_canada = 'https://github.com/ardhiraka/PFDS_sources/blob/master/Canada.xlsx?raw=true'
df_can = pd.read_excel(
    url_canada,
    sheet_name='Canada by Citizenship',
    skiprows=20,
    skipfooter=2
)

print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df_can[df_can["OdName"] == "Canada"]
# Out:
#           Type  Coverage  OdName  AREA          AreaName  REG  \
# 32  Immigrants  Citizens  Canada   905  Northern America  905
#
#              RegName  DEV            DevName  1980  ...  2004  2005  2006  \
# 32  Northern America  901  Developed regions     0  ...     0     0     0
#
#     2007  2008  2009  2010  2011  2012  2013
# 32     0     0     0     0     1     1     2
#
# [1 rows x 43 columns]

# %%
df_can.shape
# Out:
# (195, 43)

# %%
df_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
df_can.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df_can.index
# Out:
# RangeIndex(start=0, stop=195, step=1)

# %%
drop_cols = ["AREA", "REG", "DEV"]
df_can.drop(columns=drop_cols, inplace=True)
df_can.head(3)
# Out:
#          Type    Coverage       OdName AreaName          RegName  \
# 0  Immigrants  Foreigners  Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners      Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners      Algeria   Africa  Northern Africa
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# 1   560   716   561   539   620   603
# 2  4005  5393  4752  4325  3774  4331
#
# [3 rows x 40 columns]

# %%
cols_map = {
    "OdName": "Country",
    "AreaName": "Continent",
    "RegName": "Region",
}
df_can.rename(columns=cols_map, inplace=True)


# df_can.rename(columns={
#     "OdName": "Country",
#     "AreaName": "Continent",
#     "RegName": "Region",
# }, inplace=True)

df_can.head()
# Out:
#          Type    Coverage         Country Continent           Region  \
# 0  Immigrants  Foreigners     Afghanistan      Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania    Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria    Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa   Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra    Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
# 4   Developed regions     0     0     0     0  ...     0     0     1     1
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# ...

# %%
df_can["Total"] = df_can.loc[:, 1980:2013].sum(axis=1)
df_can.head(1)
# Out:
#          Type    Coverage      Country Continent         Region  \
# 0  Immigrants  Foreigners  Afghanistan      Asia  Southern Asia
#
#               DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39    47  ...  3436  3009  2652  2111
#
#    2009  2010  2011  2012  2013  Total
# 0  1746  1758  2203  2635  2004  58639
#
# [1 rows x 41 columns]

# %%
df_can.isna().sum()
# Out:
# Type         0
# Coverage     0
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_can.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
df_can.describe(include="O")
# Out:
#               Type    Coverage      Country Continent        Region  \
# count          195         195          195       195           195
# unique           1           2          195         6            22
# top     Immigrants  Foreigners  Afghanistan    Africa  Western Asia
# freq           195         194            1        54            18
#
#                    DevName
# count                  195
# unique                   2
# top     Developing regions
# freq                   147

# %%
df_can.Region
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: Region, Length: 195, dtype: object

# %%
df_can["Region"]
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: Region, Length: 195, dtype: object

# %%
df_can.loc[:, "Region"]
# Out:
# 0           Southern Asia
# 1         Southern Europe
# 2         Northern Africa
# 3               Polynesia
# 4         Southern Europe
#               ...
# 190    South-Eastern Asia
# 191       Northern Africa
# 192          Western Asia
# 193        Eastern Africa
# 194        Eastern Africa
# Name: Region, Length: 195, dtype: object

# %%
df_can[["Continent", "Region"]]
# Out:
#     Continent              Region
# 0        Asia       Southern Asia
# 1      Europe     Southern Europe
# 2      Africa     Northern Africa
# 3     Oceania           Polynesia
# 4      Europe     Southern Europe
# ..        ...                 ...
# 190      Asia  South-Eastern Asia
# 191    Africa     Northern Africa
# 192      Asia        Western Asia
# 193    Africa      Eastern Africa
# 194    Africa      Eastern Africa
#
# [195 rows x 2 columns]

# %%
# df_can["Coverage":"Region"]
df_can.loc[:, "Coverage":"Region"]
# Out:
#        Coverage         Country Continent              Region
# 0    Foreigners     Afghanistan      Asia       Southern Asia
# 1    Foreigners         Albania    Europe     Southern Europe
# 2    Foreigners         Algeria    Africa     Northern Africa
# 3    Foreigners  American Samoa   Oceania           Polynesia
# 4    Foreigners         Andorra    Europe     Southern Europe
# ..          ...             ...       ...                 ...
# 190  Foreigners        Viet Nam      Asia  South-Eastern Asia
# 191  Foreigners  Western Sahara    Africa     Northern Africa
# 192  Foreigners           Yemen      Asia        Western Asia
# 193  Foreigners          Zambia    Africa      Eastern Africa
# 194  Foreigners        Zimbabwe    Africa      Eastern Africa
#
# [195 rows x 4 columns]

# %%
df_can[["Coverage", "Country", "Continent", "Region"]]
# Out:
#        Coverage         Country Continent              Region
# 0    Foreigners     Afghanistan      Asia       Southern Asia
# 1    Foreigners         Albania    Europe     Southern Europe
# 2    Foreigners         Algeria    Africa     Northern Africa
# 3    Foreigners  American Samoa   Oceania           Polynesia
# 4    Foreigners         Andorra    Europe     Southern Europe
# ..          ...             ...       ...                 ...
# 190  Foreigners        Viet Nam      Asia  South-Eastern Asia
# 191  Foreigners  Western Sahara    Africa     Northern Africa
# 192  Foreigners           Yemen      Asia        Western Asia
# 193  Foreigners          Zambia    Africa      Eastern Africa
# 194  Foreigners        Zimbabwe    Africa      Eastern Africa
#
# [195 rows x 4 columns]

# %%
df_can.loc[:, ["Country", "Coverage", "Region", "Continent"]]
# Out:
#             Country    Coverage              Region Continent
# 0       Afghanistan  Foreigners       Southern Asia      Asia
# 1           Albania  Foreigners     Southern Europe    Europe
# 2           Algeria  Foreigners     Northern Africa    Africa
# 3    American Samoa  Foreigners           Polynesia   Oceania
# 4           Andorra  Foreigners     Southern Europe    Europe
# ..              ...         ...                 ...       ...
# 190        Viet Nam  Foreigners  South-Eastern Asia      Asia
# 191  Western Sahara  Foreigners     Northern Africa    Africa
# 192           Yemen  Foreigners        Western Asia      Asia
# 193          Zambia  Foreigners      Eastern Africa    Africa
# 194        Zimbabwe  Foreigners      Eastern Africa    Africa
#
# [195 rows x 4 columns]

# %%
df_can[['Country', 1980, 1981, 1982, 1983, 1984, 1985]] # returns a dataframe
# notice that 'Country' is string, and the years are integers. 
# for the sake of consistency, we will convert all column names to string later on.
# Out:
#             Country  1980  1981  1982  1983  1984  1985
# 0       Afghanistan    16    39    39    47    71   340
# 1           Albania     1     0     0     0     0     0
# 2           Algeria    80    67    71    69    63    44
# 3    American Samoa     0     1     0     0     0     0
# 4           Andorra     0     0     0     0     0     0
# ..              ...   ...   ...   ...   ...   ...   ...
# 190        Viet Nam  1191  1829  2162  3404  7583  5907
# 191  Western Sahara     0     0     0     0     0     0
# 192           Yemen     1     2     1     6     0    18
# 193          Zambia    11    17    11     7    16     9
# 194        Zimbabwe    72   114   102    44    32    29
#
# [195 rows x 7 columns]

# %%
df_can.loc[100:101]
# Out:
#            Type    Coverage        Country Continent           Region  \
# 100  Immigrants  Foreigners  Liechtenstein    Europe   Western Europe
# 101  Immigrants  Foreigners      Lithuania    Europe  Northern Europe
#
#                DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 100  Developed regions     1     4     2     0  ...     1     0     0     1
# 101  Developed regions     1     1     0     0  ...   167   113   108   109
#
#      2009  2010  2011  2012  2013  Total
# 100     1     0     2     1     0     40
# 101    63    57    52    77   145   2414
#
# [2 rows x 41 columns]

# %%
df_can.iloc[100:101]
# Out:
#            Type    Coverage        Country Continent          Region  \
# 100  Immigrants  Foreigners  Liechtenstein    Europe  Western Europe
#
#                DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 100  Developed regions     1     4     2     0  ...     1     0     0     1
#
#      2009  2010  2011  2012  2013  Total
# 100     1     0     2     1     0     40
#
# [1 rows x 41 columns]

# %%
df_can.head()
# Out:
#          Type    Coverage         Country Continent           Region  \
# 0  Immigrants  Foreigners     Afghanistan      Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania    Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria    Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa   Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra    Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39    47  ...  3436  3009  2652  2111
# 1   Developed regions     1     0     0     0  ...  1223   856   702   560
# 2  Developing regions    80    67    71    69  ...  3626  4807  3623  4005
# 3  Developing regions     0     1     0     0  ...     0     1     0     0
# 4   Developed regions     0     0     0     0  ...     0     1     1     0
#
#    2009  2010  2011  2012  2013  Total
# 0  1746  1758  2203  2635  2004  58639
# ...

# %%
df_can.set_index(keys="Country", inplace=True)
df_can.head()
# Out:
#                       Type    Coverage Continent           Region  \
# Country
# Afghanistan     Immigrants  Foreigners      Asia    Southern Asia
# Albania         Immigrants  Foreigners    Europe  Southern Europe
# Algeria         Immigrants  Foreigners    Africa  Northern Africa
# American Samoa  Immigrants  Foreigners   Oceania        Polynesia
# Andorra         Immigrants  Foreigners    Europe  Southern Europe
#
#                            DevName  1980  1981  1982  1983  1984  ...  2005  \
# Country                                                           ...
# Afghanistan     Developing regions    16    39    39    47    71  ...  3436
# Albania          Developed regions     1     0     0     0     0  ...  1223
# Algeria         Developing regions    80    67    71    69    63  ...  3626
# American Samoa  Developing regions     0     1     0     0     0  ...     0
# Andorra          Developed regions     0     0     0     0     0  ...     0
#
# ...

# %%
df_can.index.name
# Out:
# 'Country'

# %%
df_can.index.name = None

# %%
df_can.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States of America', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Western Sahara',
#        'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=195)

# %%
df_can.head()
# Out:
#                       Type    Coverage Continent           Region  \
# Afghanistan     Immigrants  Foreigners      Asia    Southern Asia
# Albania         Immigrants  Foreigners    Europe  Southern Europe
# Algeria         Immigrants  Foreigners    Africa  Northern Africa
# American Samoa  Immigrants  Foreigners   Oceania        Polynesia
# Andorra         Immigrants  Foreigners    Europe  Southern Europe
#
#                            DevName  1980  1981  1982  1983  1984  ...  2005  \
# Afghanistan     Developing regions    16    39    39    47    71  ...  3436
# Albania          Developed regions     1     0     0     0     0  ...  1223
# Algeria         Developing regions    80    67    71    69    63  ...  3626
# American Samoa  Developing regions     0     1     0     0     0  ...     0
# Andorra          Developed regions     0     0     0     0     0  ...     0
#
#                 2006  2007  2008  2009  2010  2011  2012  2013  Total
# ...

# %%
type(df_can.loc[["Afghanistan"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_can.loc[["Afghanistan"]]
# Out:
#                    Type    Coverage Continent         Region  \
# Afghanistan  Immigrants  Foreigners      Asia  Southern Asia
#
#                         DevName  1980  1981  1982  1983  1984  ...  2005  \
# Afghanistan  Developing regions    16    39    39    47    71  ...  3436
#
#              2006  2007  2008  2009  2010  2011  2012  2013  Total
# Afghanistan  3009  2652  2111  1746  1758  2203  2635  2004  58639
#
# [1 rows x 40 columns]

# %%
print(df_can.loc["Afghanistan"])
# Out:
# Type                 Immigrants
# Coverage             Foreigners
# Continent                  Asia
# Region            Southern Asia
# DevName      Developing regions
# 1980                         16
# 1981                         39
# 1982                         39
# 1983                         47
# 1984                         71
# 1985                        340
# 1986                        496
# 1987                        741
# 1988                        828
# 1989                       1076
# 1990                       1028
# 1991                       1378
# 1992                       1170
# 1993                        713
# 1994                        858
# 1995                       1537
# 1996                       2212
# 1997                       2555
# 1998                       1999
# 1999                       2395
# 2000                       3326
# 2001                       4067
# 2002                       3697
# 2003                       3479
# ...

# %%
df_can.iloc[0]
# Out:
# Type                 Immigrants
# Coverage             Foreigners
# Continent                  Asia
# Region            Southern Asia
# DevName      Developing regions
# 1980                         16
# 1981                         39
# 1982                         39
# 1983                         47
# 1984                         71
# 1985                        340
# 1986                        496
# 1987                        741
# 1988                        828
# 1989                       1076
# 1990                       1028
# 1991                       1378
# 1992                       1170
# 1993                        713
# 1994                        858
# 1995                       1537
# 1996                       2212
# 1997                       2555
# 1998                       1999
# 1999                       2395
# 2000                       3326
# 2001                       4067
# 2002                       3697
# 2003                       3479
# ...

# %%
df_can.iloc[0:2].transpose()
# Out:
#                   Afghanistan            Albania
# Type               Immigrants         Immigrants
# Coverage           Foreigners         Foreigners
# Continent                Asia             Europe
# Region          Southern Asia    Southern Europe
# DevName    Developing regions  Developed regions
# 1980                       16                  1
# 1981                       39                  0
# 1982                       39                  0
# 1983                       47                  0
# 1984                       71                  0
# 1985                      340                  0
# 1986                      496                  1
# 1987                      741                  2
# 1988                      828                  2
# 1989                     1076                  3
# 1990                     1028                  3
# 1991                     1378                 21
# 1992                     1170                 56
# ...

# %%
df_can.loc["Japan", 2013]
# Out:
# 982

# %%
df_can.iloc[87, -2]
# Out:
# 982

# %%
print(df_can.loc['Japan', [1980, 1981, 1982, 1983, 1984, 1985]])
print(df_can.iloc[87, [3, 4, 5, 6, 7, 8]])
# Out:
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246
# 1985    198
# Name: Japan, dtype: object
# Region          Eastern Asia
# DevName    Developed regions
# 1980                     701
# 1981                     756
# 1982                     598
# 1983                     309
# Name: Japan, dtype: object

# %%
# for i in df_can.columns:
#     if isinstance(i, int):
#         print(str(i))

# [str(i) for i in df_can.columns if isinstance(i, int)]

df_can.columns = [str(i) for i in df_can.columns]

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# df_can.columns = [str(i) for i in df_can.columns]
# df_can.columns = list(map(str, df_can.columns))
df_can.columns = [*map(str, df_can.columns)]

df_can.columns
# Out:
# Index(['Type', 'Coverage', 'Continent', 'Region', 'DevName', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
# years = df_can.loc[:, "1980":"2013"].columns.to_list()
years = [*map(str, range(1980, 2014))]

years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
condition = (df_can["Continent"] == "Asia")

print(condition)
# Out:
# Afghanistan        True
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam           True
# Western Sahara    False
# Yemen              True
# Zambia            False
# Zimbabwe          False
# Name: Continent, Length: 195, dtype: bool

# %%
df_can[condition]
# Out:
#                                                       Type    Coverage  \
# Afghanistan                                     Immigrants  Foreigners
# Armenia                                         Immigrants  Foreigners
# Azerbaijan                                      Immigrants  Foreigners
# Bahrain                                         Immigrants  Foreigners
# Bangladesh                                      Immigrants  Foreigners
# Bhutan                                          Immigrants  Foreigners
# Brunei Darussalam                               Immigrants  Foreigners
# Cambodia                                        Immigrants  Foreigners
# China                                           Immigrants  Foreigners
# China, Hong Kong Special Administrative Region  Immigrants  Foreigners
# China, Macao Special Administrative Region      Immigrants  Foreigners
# Cyprus                                          Immigrants  Foreigners
# ...

# %%
df_can.shape
# Out:
# (195, 40)

# %%
df_can.columns
# Out:
# Index(['Type', 'Coverage', 'Continent', 'Region', 'DevName', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
df_can.head()
# Out:
#                       Type    Coverage Continent           Region  \
# Afghanistan     Immigrants  Foreigners      Asia    Southern Asia
# Albania         Immigrants  Foreigners    Europe  Southern Europe
# Algeria         Immigrants  Foreigners    Africa  Northern Africa
# American Samoa  Immigrants  Foreigners   Oceania        Polynesia
# Andorra         Immigrants  Foreigners    Europe  Southern Europe
#
#                            DevName  1980  1981  1982  1983  1984  ...  2005  \
# Afghanistan     Developing regions    16    39    39    47    71  ...  3436
# Albania          Developed regions     1     0     0     0     0  ...  1223
# Algeria         Developing regions    80    67    71    69    63  ...  3626
# American Samoa  Developing regions     0     1     0     0     0  ...     0
# Andorra          Developed regions     0     0     0     0     0  ...     0
#
#                 2006  2007  2008  2009  2010  2011  2012  2013  Total
# ...

# %% [markdown]
# ## Visualization

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.__version__
# Out:
# '3.8.0'

# %%
df_can.loc["Japan", "1980":"2013"].plot()
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
mpl.style.use(["ggplot"])

# %% [markdown]
# ### Line Plots

# %%
# df_can.loc["Haiti", "1980":"2013"]
# df_can.loc["Haiti", ["1980", "1981", "1982"]
haiti = df_can.loc["Haiti", years]

# %%
haiti.plot()
# Out:
# <Axes: >

# %%
haiti.index = haiti.index.map(int)

# %%
haiti.plot(kind="line")

plt.title("Immigration from Haiti to Canada", {"fontname": "Hack"})
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")
plt.text(2000, 6000, "2010 Earthquake")

plt.show()
# Out:
# findfont: Font family 'Hack' not found.
# findfont: Font family 'Hack' not found.
# findfont: Font family 'Hack' not found.
# findfont: Font family 'Hack' not found.
# findfont: Font family 'Hack' not found.

# %%
for country in df_can.index[:5]:
    plt.clf()
    df_can.loc[country, years].plot(kind="line")

    plt.title(f"Immigration from {country} to Canada")
    plt.xlabel("Years")
    plt.ylabel("Number of Immigrants")

    plt.savefig(f"./out/{country}.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# e:\Python\Stupen-Hacktiv8\Sesi 07.ipynb Cell 60 line 9
#       <a href='vscode-notebook-cell:/e%3A/Python/Stupen-Hacktiv8/Sesi%2007.ipynb#Y113sZmlsZQ%3D%3D?line=5'>6</a> plt.xlabel("Years")
#       <a href='vscode-notebook-cell:/e%3A/Python/Stupen-Hacktiv8/Sesi%2007.ipynb#Y113sZmlsZQ%3D%3D?line=6'>7</a> plt.ylabel("Number of Immigrants")
# ----> <a href='vscode-notebook-cell:/e%3A/Python/Stupen-Hacktiv8/Sesi%2007.ipynb#Y113sZmlsZQ%3D%3D?line=8'>9</a> plt.savefig(f"./out/{country}.png")
#
# File c:\Users\acer_\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# ...

# %%
China_India = df_can.loc[["India", "China"], years]
China_India
# Out:
#        1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# India  8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
# China  5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
#
#         2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# India  28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China  36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 34 columns]

# %%
China_India.transpose().plot(kind="line")

plt.title("Immigration from China and India")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %%
df_top5 = df_can.sort_values(by="Total", ascending=False).iloc[:5, 5:-1]
df_top5 = df_top5.transpose()
df_top5.rename(columns={"United Kingdom of Great Britain and Northern Ireland": "UK"}, inplace=True)
# df_top5.tail()

df_top5.plot(kind="line", figsize=(14, 5))

plt.title("Immigration Trend of Top 5 Countries")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %% [markdown]
# ### Area

# %%
df_top5.tail()
# Out:
#       India  China    UK  Philippines  Pakistan
# 2009  29456  29622  8876        28573      7217
# 2010  34235  30391  8724        38617      6811
# 2011  27509  28502  6204        36765      7468
# 2012  30933  33024  6195        34315     11227
# 2013  33087  34129  5827        29544     12603

# %%
df_top5.plot(
    kind="area",
    figsize=(14, 5),
    stacked=True,
    alpha=0.5,
)
df_top5.loc[years].transpose().sum().plot(color="blue")


plt.title("Immigration Trend of Top 5 Countries")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %%
df_top5.plot(
    kind="area",
    figsize=(14, 5),
    stacked=False,
    # alpha=0.5,
)
# df_top5.loc[years].transpose().sum().plot(color="blue")

plt.title("Immigration Trend of Top 5 Countries")
plt.xlabel("Years")
plt.ylabel("Number of Immigrants")

plt.show()

# %%
ax = df_top5.plot(
    kind="area",
    figsize=(14, 5),
    stacked=True,
    alpha=0.5,
)

ax.set_title("Immigration Trend of Top 5 Countries")
ax.set_xlabel("Years")
ax.set_ylabel("Number of Immigrants")

plt.show()

# %%
df_least5 = df_can.sort_values(by="Total", ascending=True).iloc[:5, 5:-1]
df_least5 = df_least5.transpose() 

df_least5.plot(
    kind='area', 
    alpha=0.45, # 0-1, default value a= 0.5
    stacked=True,
    figsize=(14, 5),
)

plt.title('Immigration Trend of Least 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %%
ax = df_least5.plot(
    kind='area', 
    alpha=0.45, # 0-1, default value a= 0.5
    stacked=True,
    figsize=(14, 5),
)

ax.set_title('Immigration Trend of Least 5 Countries')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('Years')

plt.show()

# %% [markdown]
# ### Histograms

# %%
df_can["2013"].head()
# Out:
# Afghanistan       2004
# Albania            603
# Algeria           4331
# American Samoa       0
# Andorra              1
# Name: 2013, dtype: int64

# %%
df_can["2013"].sort_values(ascending=False)
# Out:
# China                         34129
# India                         33087
# Philippines                   29544
# Pakistan                      12603
# Iran (Islamic Republic of)    11291
#                               ...
# San Marino                        0
# Palau                             0
# Guinea-Bissau                     0
# Tuvalu                            0
# Marshall Islands                  0
# Name: 2013, Length: 195, dtype: int64

# %%
count, bin_edges = np.histogram(df_can["2013"], bins=10)

print(count)
print(bin_edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df_can["2013"].plot(kind="hist", figsize=(8, 5))
plt.title('Histogram of Immigration from 195 Countries in 2013') # add a title to the histogram
plt.ylabel('Number of Countries') # add y-label
plt.xlabel('Number of Immigrants') # add x-label

plt.show()

# %%
# 'bin_edges' is a list of bin intervals
count, bin_edges = np.histogram(df_can['2013'])

df_can['2013'].plot(kind='hist', figsize=(8, 5), xticks=bin_edges)

plt.title('Histogram of Immigration from 195 countries in 2013') # add a title to the histogram
plt.ylabel('Number of Countries') # add y-label
plt.xlabel('Number of Immigrants') # add x-label

plt.show()

# %%
df_nord = df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
df_nord.tail()
# Out:
#       Denmark  Norway  Sweden
# 2009       81      75     167
# 2010       92      46     159
# 2011       93      49     134
# 2012       94      53     140
# 2013       81      59     140

# %%
df_nord.sum()
# Out:
# Denmark    3901
# Norway     2327
# Sweden     5866
# dtype: int64

# %%
df_nord.sort_values("Sweden", ascending=False).head()
# Out:
#       Denmark  Norway  Sweden
# 1981      293      77     308
# 1980      272     116     281
# 1982      299     106     222
# 2005       62      57     205
# 1993      186      92     203

# %%
# 'bin_edges' is a list of bin intervals
count, bin_edges = np.histogram(df_nord)

df_nord.plot(kind='hist', figsize=(8, 5), xticks=bin_edges, alpha=0.5)

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013') # add a title to the histogram
plt.ylabel('Number of Years') # add y-label
plt.xlabel('Number of Immigrants') # add x-label

plt.show()

# %%
# let's get the x-tick values
count, bin_edges = np.histogram(df_nord, 15)

# un-stacked histogram
df_nord.plot(
    kind ='hist', 
    figsize=(10, 6),
    bins=15,
    alpha=0.6,
    xticks=bin_edges,
    color=['coral', 'darkslateblue', 'mediumseagreen']
)

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
import matplotlib
for name, hex in matplotlib.colors.cnames.items():
    print(name, hex)
# Out:
# aliceblue #F0F8FF
# antiquewhite #FAEBD7
# aqua #00FFFF
# aquamarine #7FFFD4
# azure #F0FFFF
# beige #F5F5DC
# bisque #FFE4C4
# black #000000
# blanchedalmond #FFEBCD
# blue #0000FF
# blueviolet #8A2BE2
# brown #A52A2A
# burlywood #DEB887
# cadetblue #5F9EA0
# chartreuse #7FFF00
# chocolate #D2691E
# coral #FF7F50
# cornflowerblue #6495ED
# cornsilk #FFF8DC
# crimson #DC143C
# cyan #00FFFF
# darkblue #00008B
# darkcyan #008B8B
# darkgoldenrod #B8860B
# darkgray #A9A9A9
# darkgreen #006400
# darkgrey #A9A9A9
# darkkhaki #BDB76B
# darkmagenta #8B008B
# darkolivegreen #556B2F
# darkorange #FF8C00
# darkorchid #9932CC
# darkred #8B0000
# darksalmon #E9967A
# darkseagreen #8FBC8F
# darkslateblue #483D8B
# darkslategray #2F4F4F
# darkslategrey #2F4F4F
# darkturquoise #00CED1
# darkviolet #9400D3
# deeppink #FF1493
# deepskyblue #00BFFF
# dimgray #696969
# dimgrey #696969
# dodgerblue #1E90FF
# firebrick #B22222
# floralwhite #FFFAF0
# forestgreen #228B22
# fuchsia #FF00FF
# ...

# %%
df_cof = df_can.loc[['Greece', 'Albania', 'Bulgaria'], years]
df_cof = df_cof.transpose() 

count, bin_edges = np.histogram(df_cof, 15)
df_cof.plot(kind ='hist',
            figsize=(10, 6),
            bins=15,
            alpha=0.35,
            xticks=bin_edges,
            color=['coral', 'darkslateblue', 'mediumseagreen']
            )

plt.title('Histogram of Immigration from Greece, Albania, and Bulgaria from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')
plt.show()

# %% [markdown]
# ### Bar

# %%
# step 1: get the data
df_iceland = df_can.loc['Iceland', years]
df_iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
# step 2: plot data
df_iceland.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

plt.show()

# %% [markdown]
# - s: str, the text of annotation.
#
# - xy: Tuple specifying the (x,y) point to annotate (in this case, end point of arrow).
#
# - xytext: Tuple specifying the (x,y) point to place the text (in this case, start point of arrow).
#
# - xycoords: The coordinate system that xy is given in - 'data' uses the coordinate system of the object being annotated (default).
#
# - arrowprops: Takes a dictionary of properties to draw the arrow:
#
# - arrowstyle: Specifies the arrow style, '->' is standard arrow.
#
# - connectionstyle: Specifies the connection type. arc3 is a straight line.
#
# - color: Specifes color of arror.
#
# - lw: Specifies the line width.
#
# - rotation: rotation angle of text in degrees (counter clockwise)
#
# - va: vertical alignment of text [‘center’ | ‘top’ | ‘bottom’ | ‘baseline’]
#
# - ha: horizontal alignment of text [‘center’ | ‘right’ | ‘left’]

# %%
df_iceland.plot(kind='bar', figsize=(10, 6), rot=90) 

plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.title('Icelandic Immigrants to Canada from 1980 to 2013')

# Annotate arrow
plt.annotate('',                      # s: str. will leave it blank for no text
             xy=(32, 70),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )

# Annotate Text
plt.annotate('2008 - 2011 Financial Crisis', # text to display
             xy=(28, 30),                    # start the text at at point (year 2008 , pop 30)
             rotation=72.5,                  # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
             ha='left',                      # want the text to be horizontally 'left' algned.
            )

plt.show()

# %%
### type your answer here

df_can.sort_values(by='Total', ascending=True, inplace=True)
df_top15 = df_can['Total'].tail(15)
df_top15
# Out:
# Romania                                                  93585
# Viet Nam                                                 97146
# Jamaica                                                 106431
# France                                                  109091
# Lebanon                                                 115359
# Poland                                                  139241
# Republic of Korea                                       142581
# Sri Lanka                                               148358
# Iran (Islamic Republic of)                              175923
# United States of America                                241122
# Pakistan                                                241600
# Philippines                                             511391
# United Kingdom of Great Britain and Northern Ireland    551500
# China                                                   659962
# India                                                   691904
# ...

# %%
### type your answer here

df_top15.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Conuntries Contributing to the Immigration to Canada between 1980 - 2013')
for index, value in enumerate(df_top15): 
    label = format(int(value), ',') # format int with commas
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
# group countries by continents and apply sum() function 
df_continents = df_can.groupby('Continent')[years + ["Total"]].sum()

# note: the output of the groupby method is a `groupby' object. 
# we can not use it further until we apply a function (eg .sum())
print(type(df_can.groupby('Continent')))

df_continents.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989  ...    2005  \
# Continent                                                    ...
# Africa                            3782   7494   7552   9894  ...   27523
# Asia                             28739  43203  47454  60256  ...  159253
# Europe                           24370  46698  54726  60893  ...   35955
# Latin America and the Caribbean  21179  28471  21924  25060  ...   24747
# ...

# %%
# autopct create %, start angle represent starting point
df_continents['Total'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continents['Total'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %%
### type your answer here
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.05, 0.15] # ratio for each continent with which to offset each wedge.

df_continents['2013'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent Year 2013', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %% [markdown]
# ### Boxplot

# %%
# to get a dataframe, place extra square brackets around 'Japan'.
df_japan = df_can.loc[['Japan'], years].transpose()
df_japan.head()
# Out:
#       Japan
# 1980    701
# 1981    756
# 1982    598
# 1983    309
# 1984    246

# %%
df_japan.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of Japanese Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_japan.describe()
# Out:
#              Japan
# count    34.000000
# mean    814.911765
# std     337.219771
# min     198.000000
# 25%     529.000000
# 50%     902.000000
# 75%    1079.000000
# max    1284.000000

# %%
### type your answer here

df_CI = df_can.loc[(['China', 'India']), years].transpose()
df_CI.head()
# Out:
#       China  India
# 1980   5123   8880
# 1981   6682   8670
# 1982   3308   8147
# 1983   1863   7338
# 1984   1527   5704

# %%
df_CI.describe()
# Out:
#               China         India
# count     34.000000     34.000000
# mean   19410.647059  20350.117647
# std    13568.230790  10007.342579
# min     1527.000000   4211.000000
# 25%     5512.750000  10637.750000
# 50%    19945.000000  20235.000000
# 75%    31568.500000  28699.500000
# max    42584.000000  36210.000000

# %%
df_CI.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of China and India Immigrants from 1980 - 2013')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
# horizontal box plots
df_CI.plot(kind='box', figsize=(10, 7), color='blue', vert=False)

plt.title('Box plots of Immigrants from China and India (1980 - 2013)')
plt.xlabel('Number of Immigrants')

plt.show()

# %% [markdown]
# ### Subplots

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**

# Subplot 1: Box plot
df_CI.plot(kind='box', color='blue', vert=False, figsize=(20, 6), ax=ax0) # add to subplot 1
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_CI.plot(kind='line', figsize=(20, 6), ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Immigrants from China and India (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')

plt.show()

# %%
### type your answer here
df_top15 = df_can.sort_values(['Total'], ascending=False, axis=0).head(15)
df_top15
# Out:
#                                                           Type    Coverage  \
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# United States of America                            Immigrants  Foreigners
# Iran (Islamic Republic of)                          Immigrants  Foreigners
# Sri Lanka                                           Immigrants  Foreigners
# Republic of Korea                                   Immigrants  Foreigners
# Poland                                              Immigrants  Foreigners
# Lebanon                                             Immigrants  Foreigners
# ...

# %%
years_80s = list(map(str, range(1980, 1990))) 
years_90s = list(map(str, range(1990, 2000))) 
years_00s = list(map(str, range(2000, 2010))) 

df_80s = df_top15.loc[:, years_80s].sum(axis=1) 
df_90s = df_top15.loc[:, years_90s].sum(axis=1) 
df_00s = df_top15.loc[:, years_00s].sum(axis=1)

new_df = pd.DataFrame({'1980s': df_80s, '1990s': df_90s, '2000s':df_00s}) 
new_df.head()
# Out:
#                                                      1980s   1990s   2000s
# India                                                82154  180395  303591
# China                                                32003  161528  340385
# United Kingdom of Great Britain and Northern Ir...  179171  261966   83413
# Philippines                                          60764  138482  172904
# Pakistan                                             10591   65302  127598

# %%
new_df.describe()
# Out:
#                1980s          1990s          2000s
# count      15.000000      15.000000      15.000000
# mean    44418.333333   85594.666667   97471.533333
# std     44190.676455   68237.560246  100583.204205
# min      7613.000000   30028.000000   13629.000000
# 25%     16698.000000   39259.000000   36101.500000
# 50%     30638.000000   56915.000000   65794.000000
# 75%     59183.000000  104451.500000  105505.500000
# max    179171.000000  261966.000000  340385.000000

# %%
### type your answer here
new_df.plot(kind='box', figsize=(10, 6))
plt.title('Immigration from top 15 countries for decades 80s, 90s and 2000s')
plt.show()

# %% [markdown]
# ### Scatter

# %%
# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df_can[years].sum(axis=0))

# change the years to type int (useful for regression later on)
df_tot.index = map(int, df_tot.index)

# reset the index to put in back in as a column in the df_tot dataframe
df_tot.reset_index(inplace = True)

# rename columns
df_tot.columns = ['year', 'total']

# view the final dataframe
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
df_countries = df_can.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
df_total = pd.DataFrame(df_countries.sum(axis=1))
df_total.reset_index(inplace=True)
df_total.columns = ['year', 'total']
df_total['year'] = df_total['year'].astype(int)
df_total.head()
# Out:
#    year  total
# 0  1980    669
# 1  1981    678
# 2  1982    627
# 3  1983    333
# 4  1984    252

# %%
df_total.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')
plt.title('Immigration from Denmark, Norway, and Sweden to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.show()

# %% [markdown]
# ### Bubble

# %%
df_can_t = df_can[years].transpose() # transposed dataframe

# cast the Years (the index) to type int
df_can_t.index = map(int, df_can_t.index)

# let's label the index. This will automatically be the column name when we reset the index
df_can_t.index.name = 'Year'

# reset index to bring the Year in as a column
df_can_t.reset_index(inplace=True)

# view the changes
df_can_t.head()
# Out:
#    Year  Palau  Marshall Islands  Western Sahara  San Marino  New Caledonia  \
# 0  1980      0                 0               0           1              0
# 1  1981      0                 0               0           0              0
# 2  1982      0                 0               0           0              0
# 3  1983      0                 0               0           0              0
# 4  1984      0                 0               0           0              0
#
#    American Samoa  Tuvalu  Sao Tome and Principe  Vanuatu  ...  Poland  \
# 0               0       0                      0        0  ...     863
# 1               1       1                      0        0  ...    2930
# 2               0       0                      0        0  ...    5881
# 3               0       0                      0        0  ...    4546
# 4               0       1                      0        0  ...    3588
#
#    Republic of Korea  Sri Lanka  Iran (Islamic Republic of)  \
# ...

# %%
# normalize Brazil data
norm_brazil = (df_can_t['Brazil'] - df_can_t['Brazil'].min()) / (df_can_t['Brazil'].max() - df_can_t['Brazil'].min())

# normalize Argentina data
norm_argentina = (df_can_t['Argentina'] - df_can_t['Argentina'].min()) / (df_can_t['Argentina'].max() - df_can_t['Argentina'])

# %%
# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,                  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 10,  # pass in weights 
                    xlim=(1975, 2015)
                   )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10,
                    ax = ax0
                   )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 - 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')
# Out:
# Error in callback <function _draw_all_if_interactive at 0x00000205275D3600> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\acer_\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File c:\Users\acer_\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\acer_\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
# ...
